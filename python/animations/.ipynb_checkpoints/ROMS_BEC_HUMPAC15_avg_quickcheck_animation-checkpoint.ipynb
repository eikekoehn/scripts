# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import os
import sys
import cartopy.crs as ccrs
import xarray as xr
from matplotlib import cm
import cmocean as cmo

# %%
##load datasets
#ds = xr.open_dataset('/net/kryo/work/koehne/roms/analysis/regridded_data/pactcs60/testrun_T10_pactcs60/avg/z_pactcs601_602_603_604_605_606_607_608_609_avg.nc')
ds = xr.open_dataset('/net/kryo/work2/fana/hindcast_bec/hindcast/output/avg/z_avg_2016_0-200m.nc')
print('Data Loaded')
##load grid
#grid = xr.open_dataset('/net/kryo/work/koehne/roms/input/pactcs60/pactcs60_grd.nc')
grid = xr.open_dataset('/net/nardus/work/Ana/masks_and_maps/humpac_grids/humpac15_sm5rf015_grd.nc')
print('Grid Loaded')
# Out:
# Data Loaded
# Grid Loaded

# %%
## SET THE PLOT CONTENTS - ONLY CHOOSE THE VARIABLE TO SHOW AND THE REST SHOULD BE CHOSEN ACCORDINGLY

# Choose the Variable to show
varname = 'O2'
data = eval('ds.'+ varname)

# choose depth level
dix = 0
print(ds.depth[dix].values,'m')


# Choose data range (for colorbar)
if varname=='salt':
    vmin,vmax = 30,37
elif varname=='temp':
    vmin,vmax = 0,30
elif varname=='u':
    vmin,vmax=-1.,1.
elif varname=='v':
    vmin,vmax=-1.,1.
elif varname=='O2':
    vmin,vmax=0.,301.
elif varname=='NO3':
    vmin,vmax=0.,50.
    
# Choose grid
rhogridvars = ['salt','temp','O2','NO3']
if varname in rhogridvars:
    lons = grid.lon_rho
    lats = grid.lat_rho
elif varname == 'u':
    lons = grid.lon_u
    lats = grid.lat_u
elif varname == 'v':
    lons = grid.lon_v
    lats = grid.lat_v
#elif varname == 'O2':
#    lons = grid.lon_rho
#    lats = grid.lat_rho  
    
# choose levels (for Colorbar):
levels = 20
colors = np.linspace(vmin,vmax,levels)

# choose title (units) for colorbar
units = data.units

#choose plot title
plot_title = data.long_name+' at '+str(ds.depth[dix].values)+' m'

# choose colormaps
if varname=='salt':
    colmap = cmo.cm.haline
elif varname=='temp':
    colmap = cmo.cm.thermal
elif varname=='u' or varname == 'v':
    colmap = cmo.cm.delta
elif varname=='O2':
    colmap = cmo.cm.oxy
elif varname=='NO3':
    colmap = cmo.cm.matter

# center_longitude
cl = 200.

# movie preferences
frames = 12
interval = 200

# choose timeseries location
etacho = 100
xicho = 300
print(lats.shape)
print(lats[etacho,xicho])
print(lons[etacho,xicho])
# Out:
# -0.0 m
# (1009, 701)
# <xarray.DataArray 'lat_rho' ()>
# array(-11.64737)
# Coordinates:
#     lon_rho  float64 276.9
#     lat_rho  float64 -11.65
# Attributes:
#     long_name:  longitude of RHO-points
#     units:      degree_north
# <xarray.DataArray 'lon_rho' ()>
# array(276.924322)
# Coordinates:
#     lon_rho  float64 276.9
#     lat_rho  float64 -11.65
# Attributes:
#     long_name:  longitude of RHO-points
#     units:      degree_east

# %%
#Animate surface using contourf
fig = plt.figure(figsize=(20,12))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=cl))
ax.set_extent([100,300,-85, 85], crs=ccrs.PlateCarree())
l = ax.contourf(lons-cl,lats,data[1,dix,:,:],colors,extend="max",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
ax.coastlines()
ax.set_title(plot_title)
cbar = plt.colorbar(l)
cbar.set_label(units, rotation=270)
#plt.show()
def animate(i):
    l.collections = []
    ax.contourf(lons-cl,lats,data[i+1,dix,:,:],colors,extend="max",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=frames,interval=interval)

from IPython.display import HTML
HTML(ani.to_jshtml())

# %%
# Animate surface using contourf
cl = 280.
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(121,projection=ccrs.PlateCarree(central_longitude=cl))
ax.set_extent([cl-25.,cl+25.,-35, 10], crs=ccrs.PlateCarree())
l = ax.contourf(lons-cl,lats,data[1,dix,:,:],colors,extend="both",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
l2 = ax.scatter(lons[etacho,xicho]-cl,lats[etacho,xicho],70,'k',marker='x')
ax.coastlines()
ax.set_title(plot_title)
cbar = plt.colorbar(l,fraction=0.038)
cbar.set_label(units, rotation=270)

#plt.show()
def animate(i):
    l.collections = []
    l2.collections = []
    ax.contourf(lons-cl,lats,data[i,dix,:,:],colors,extend="max",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
    ax.set_title('Time series at location')
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=frames,interval=interval)

from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img9eb94f59f77d4f67821fd4d95362a716">
#     <br>
#     <input id="_anim_slider9eb94f59f77d4f67821fd4d95362a716" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim9eb94f59f77d4f67821fd4d95362a716.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim9eb94f59f77d4f67821fd4d95362a716.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select9eb94f59f77d4f67821fd4d95362a716" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9eb94f59f77d4f67821fd4d95362a716";
#     var slider_id = "_anim_slider9eb94f59f77d4f67821fd4d95362a716";
#     var loop_select_id = "_anim_loop_select9eb94f59f77d4f67821fd4d95362a716";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvqOYd8AAAIABJREFUeJzs3Xmc1XXd///nmUVAYJgRFQERzBIQ\
# QUL9auaS3lLL5Xu5pGmYlpT1Nfu5hpZm5uWWaerVophal2ZambmlZVaWlxtuuOKSCxouuLAIIszM\
# Ob8/irlAQQaYz2zc77fb3G4w53w+n/c5TA0+eM37U6pUKpUAAAAAAEAbq+roBQAAAAAA0D0J0AAA\
# AAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEa\
# AAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAoh\
# QAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABA\
# IQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAA\
# ACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAA\
# AAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAG\
# AAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII\
# 0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQ\
# CAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAA\
# AAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAA\
# AABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKAB\
# AAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBAC\
# NAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAU\
# QoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAA\
# gEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAA\
# AABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgA\
# AAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQA\
# DQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACF\
# EKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAA\
# oBACNAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAA\
# AAAUQoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoA\
# AAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEE

# %%
#Animate surface using contourf
cl = 280.
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(121,projection=ccrs.PlateCarree(central_longitude=cl))
ax.set_extent([cl-25.,cl+25.,-35, 10], crs=ccrs.PlateCarree())
l = ax.contourf(lons-cl,lats,data[1,dix,:,:],colors,extend="both",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
l2 = ax.scatter(lons[etacho,xicho]-cl,lats[etacho,xicho],70,'k',marker='x')
ax.coastlines()
ax.set_title(plot_title)
cbar = plt.colorbar(l,fraction=0.038)
cbar.set_label(units, rotation=270)

ax2 = fig.add_subplot(122)
ax2.axis([0,12,np.min(data[:,dix,etacho,xicho]),np.max(data[:,dix,etacho,xicho])])
l3, = ax2.plot([],[])

#plt.show()
def animate(i):
    l.collections = []
    l2.collections = []
    ax.contourf(lons-cl,lats,data[i,dix,:,:],colors,extend="max",cmap=colmap,transform=ccrs.PlateCarree(central_longitude=cl))
    ax.scatter(lons[etacho,xicho]-cl,lats[etacho,xicho],50,'k',marker='x')
    ax.set_title('Time series at location')
    l3.set_data(np.arange(i+1),data[:i+1,dix,etacho,xicho])
    ax2.set_title(str(np.arange(i+1)))
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=frames,interval=interval)

from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6f260206cdaf461e83d4a86a2b2db59e">
#     <br>
#     <input id="_anim_slider6f260206cdaf461e83d4a86a2b2db59e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6f260206cdaf461e83d4a86a2b2db59e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6f260206cdaf461e83d4a86a2b2db59e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6f260206cdaf461e83d4a86a2b2db59e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6f260206cdaf461e83d4a86a2b2db59e";
#     var slider_id = "_anim_slider6f260206cdaf461e83d4a86a2b2db59e";
#     var loop_select_id = "_anim_loop_select6f260206cdaf461e83d4a86a2b2db59e";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvqOYd8AAAIABJREFUeJzs3XmY1nW9//HXPQsDAsOMoAiI4LFS\
# RBYRj7um11HL5ZdLeixMK8rTzyzXo+auuWWaWpZLaqV58pQpLgfLY0Z1XHNBFElpAQ0XXFhEEWa5\
# f390mJ8IwgDzZRYej+ua6xru5ft93zdTI8/5zOdbKpfL5QAAAAAAQBuraO8BAAAAAADomgRoAAAA\
# AAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0A\
# AAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCg\
# AQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAAAKAQ\
# AjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAA\
# FEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAA\
# AIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMA\
# AAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAAAKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRo\
# AAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAAAAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiE\
# AA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEaAAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAA\
# hRCgAQAAAAAohAANAAAAAEAhBGgAAAAAAAohQAMAAAAAUAgBGgAAAACAQgjQAAAAAAAUQoAGAAAA\
# AKAQAjQAAAAAAIUQoAEAAAAAKIQADQAAAABAIQRoAAAAAAAKIUADAAAAAFAIARoAAAAAgEII0AAA\
# AAAAFEKABgAAAACgEAI0AAAAAACFEKABAAAAACiEAA0AAAAAQCEEaAAAAAAACiFAAwAAAABQCAEa\
# AAAAAIBCCNAAAAAAABRCgAYAAAAAoBACNAAAAAAAhRCgAQAAAAAohAANAAAALKVUKqVnz545/fTT\
# W/X4s88+Oz179kypVEpjY2PB0wHQmZTK5XK5vYcAAAAAOo5SqZTp06fnIx/5SMttkydPzvjx4zNt\
# 2rQMGzYsN9xwQ0aPHt1y/4wZM7LpppumoaEhVVVV7TE2AB2QFdAAAADACi1evDif+tSncvjhh2fO\
# nDk58sgj86lPfSqLFy9u79EA6OAEaAAAAGCFJk2alMbGxhx33HGpqanJ17/+9ZTL5TzwwAPtPRoA\
# HZwADQAAAKzQ1KlTM3LkyJRKpZbbRo4cmalTp7bjVAB0BgI0AAAAsEILFixInz59lrqtT58+efvt\
# t9tpIgA6CwEaAAAAWKFevXpl/vz5S902f/789O7du50mAqCzEKABAACAFRo+fHimTJmScrncctuU\
# KVMyfPjwdpwKgM5AgAYAAABW6OMf/3gqKyvz3e9+N4sWLcpVV12VJNljjz3aeTIAOjoBGgAAAFih\
# bt26ZcKECbnppptSV1eXG2+8MRMmTEi3bt3aezQAOrhS+f2/PwMAAACs87p3756ampp8/etfzze/\
# +c2VPv7cc8/Nd77znSxatCjvvPNOKisr18KUAHQGAjQAAAAAAIWwBQcAAAAAAIUQoAEAAAAAKIQA\
# DQAAAABAIaraewAAAKBz69evX4YOHdreYwAABZkxY0beeOON9h6DTkqABgAA1sjQ

# %%
np.shape(data[:,:,etacho,xicho].T)
# Out:
# (33, 108)

# %%
# make a depth-time diagram of the data at the chosen location
plt.subplots()
plt.contourf(np.arange(108),data.depth,data[:,:,etacho,xicho].T,levels=np.linspace(0,200,10),extend="max")
plt.ylim([-1500,0])
plt.colorbar()
plt.show()
